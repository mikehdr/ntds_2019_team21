# %% [markdown]
# # Steam Data Collection

# %% [markdown]
# ![steam_logo](https://buy.thewitcher.com/img/shops/steam.svg)

# %% [markdown]
# Fast-forward a little over 10 years and the <a href="https://en.wikipedia.org/wiki/Steam_(software)">Steam Store</a> is huge, ubiquitous as the home of PC gaming and distribution. Whilst physical copies still just about feel at home on consoles, the PC market has [long since moved digital](https://www.pcgamer.com/uk/analyst-says-digital-sales-made-up-92-percent-of-pc-game-market-in-2013/). In case you are not familiar, Steam is a digital store for purchasing, downloading and playing video games. It hosts a variety of community features, allows pushing game updates to users automatically, and gathers news stories relevant to each title. It's a bit like [Google's Play Store](https://play.google.com) or [Apple's App Store](https://www.apple.com/uk/ios/app-store/) for phones.
#
# A large part of Steam's success as a platform is due to its use of frequent sales, convenience as a unified digital game library, and the aforementioned shift to digital over physical. Whilst other platforms are emerging and gaining traction, there is likely no better resource for examining gaming over the last decade. With that in mind, if we can construct a dataset from Steam's data, we will have access to a wealth of information of more than [ 30,000 games](https://store.steampowered.com/about/) released since 2003, when Steam first launched.

# %% [markdown]
# ## Project Goals
#
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# The motivation for this project is to download, process and analyse a data set of Steam apps (games) from the Steam store, and gain insights into what makes a game more successful in terms of sales, play-time and ratings. We will imagine that we have been approached by a company hoping to develop and release a new title, using the findings we provide them to inform decisions about how best to manage their budget and hopefully increase the success of their next release.
#
# The first step will be tackling data collection - the actual retrieval of data from Steam's servers and databases. In the future we'll look at cleaning the data, transforming it into a more useful state, then on to data exploration and analysis. Finally we'll summarise our findings in a non-technical report which would be sent to the fictional company in question.
#
# <!-- PELICAN_END_SUMMARY -->
#
# At the end of the data collection and cleaning stages, we'd like to end up with a table or database like this:
#
# name | id | information | owners | price | rating
# --- | --- | --- | --- | --- | ---
# awesome game | 100 | genres, descriptors, variables | 100,000 | 9.99 .- | 9/10
# generic shooter 4 | 200 | just a regular shooter, teabag option available | 50,000 | 39.99 .- | 6/10
# ... | ... | ... | ... | ... | ...
#
# We can then interrogate the data, and investigate whether particular attributes tend to result in more successful games. Metrics like ownership and ratings should help define the success of a title.
#
# ## Data Acquisition
#
# There are a number of ways to get this information. Obviously we could search the web (and especially [kaggle](https://www.kaggle.com/datasets)) for existing datasets, however to avoid letting someone else get away with all that hard work (and mainly for the purposes of learning) we'll be acquiring all the data ourselves from scratch.
#
# Often when generating data the best place to start is to check for APIs. Fortunately Valve (the company behind Steam) make one available at https://partner.steamgames.com/. An [API](https://en.wikipedia.org/wiki/Application_programming_interface) such as this allows anyone to interface with data on a website in a controlled way, usually providing a host of useful features to the end-user. Typically an API is a great way for developers to allow access to databases and information on a server. Unfortunately this documentation doesn't include all access points, but others have documented this for us. [This](https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI) documentation of the StorefrontAPI will be particularly useful.
#
# We'll be able to get good information about the details of each game from the Steam API, however we're still missing information about popularity and sales. Luckily we can easily get this data from another website, SteamSpy.
#
# [SteamSpy](https://steamspy.com/about) is a Steam stats-gathering service and crucially has data easily available through its own API (documentation [here](https://steamspy.com/api.php)). It provides a number of useful metrics including an estimation for total owners of each game.
#
# We'll be retrieving data from both APIs and combining them to form our dataset. For the purposes of this project, we'll be performing as little data cleaning as possible at this stage, providing 'dirty' data for data cleaning, the next step in this project.
#
# ## Section outline:
#
# - Create an app list from SteamSpy API using 'all' request
# - Retrieve individual app data from Steam API, by iterating through app list
# - Retrieve individual app data from SteamSpy API, by iterating through app list
# - Export app list, Steam data and SteamSpy data to csv files
#
# ## API references:
#
# - https://partner.steamgames.com/doc/webapi
# - https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI
# - https://steamapi.xpaw.me/#
# - https://steamspy.com/api.php
#
#
# ## Import Libraries
#
# We begin by importing the libraries we will be using. We start with [standard library imports](https://docs.python.org/3/library/), or those available by default in Python, then import the third-party packages. We'll be using [requests](https://2.python-requests.org/en/master/) to handle interacting with the APIs, then the popular [pandas](http://pandas.pydata.org/pandas-docs/stable/) and [numpy](https://docs.scipy.org/doc/numpy/index.html) libraries for handling the downloaded data.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# Number of game processed (In our case, we wanted to parse all the games [-1 indicates this case])
end = -1

# Identifier to differentiate the different versions of the original data
data_id='1'

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

# %% [markdown]
# Next, we define a general, all-purpose function to process get requests from an API, supplied through a URL parameter. A dictionary of parameters can be supplied which is passed into the get request automatically, depending on the requirements of the API.
#
# Rather than simply returning the response, we handle a couple of scenarios to help automation. Occasionally we encounter an SSL Error, in which case we simply wait a few seconds then try again (by recursively calling the function). When this happens, and generally throughout this project, we provide quite verbose feedback to show when these errors are encountered and how they are handled.
#
# Sometimes there is no response when a request is made (returns None). This usually happens when too many requests are made in a short period of time, and the polling limit has been reached. We try to avoid this by pausing briefly between requests, as we'll see later, but in case we breach the polling limit we wait 10 seconds then try again.
#
# Handling these errors in this way ensures that our function almost always returns the desired response, which we return in json format to make processing easier.

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

# %% [markdown]
# ## Generate List of App IDs
#
# Every app on the steam store has a unique app ID. Whilst different apps can have the same name, they can't have the same ID. This will be very useful to us for identifying apps and eventually merging our tables of data.
#
# Before we get to that, we need to generate a list of app ids which we can use to build our data sets. It's possible to generate one from the Steam API, however this has over 70,000 entries, many of which are demos and videos with no way to tell them apart. Instead, SteamSpy provides an 'all' request, supplying some information about the apps they track. It doesn't supply all information about each app, so we still need to request this information individually, but it provides a good starting point.
#
# Because many of the return fields are strings containing commas and other punctuation, it is easiest to read the response into a pandas dataframe, and export the required appid and name fields to a csv. We could keep only the appid column as a list or pandas series, but it may be useful to keep the app name at this stage.

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
app_list.to_csv('./data/download/app_list'+data_id+'.csv', index=False)    # If you want to start parsing the steam database by yourself, just uncomment this line

# instead read from stored csv
app_list = pd.read_csv('./data/download/app_list'+data_id+'.csv')

# display first few rows
app_list.head()
len(app_list)
# Out:
# 33099

# %% [markdown]
# ## Define Download Logic
#
# Now we have the `app_list` dataframe, we can iterate over the app IDs and request individual app data from the servers. Here we set out our logic to retrieve and process this information, then finally store the data as a csv file.
#
# Because it takes a long time to retrieve the data, it would be dangerous to attempt it all in one go as any errors or connection time-outs could cause the loss of all our data. For this reason we define a function to download and process the requests in batches, appending each batch to an external file and keeping track of the highest index written in a separate file.
#
# This not only provides security, allowing us to easily restart the process if an error is encountered, but also means we can complete the download across multiple sessions.
#
# Again, we provide verbose output for rows exported, batches complete, time taken and estimated time remaining.

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %% [markdown]
# Next we define some functions to handle and prepare the external files.
#
# We use `reset_index` for testing and demonstration, allowing us to easily reset the index in the stored file to 0, effectively restarting the entire download process.
#
# We define `get_index` to retrieve the index from file, maintaining persistence across sessions. Every time a batch of information (app data) is written to file, we write the highest index within `app_data` that was retrieved. As stated, this is partially for security, ensuring that if there is an error during the download we can read the index from file and continue from the end of the last successful batch. Keeping track of the index also allows us to pause the download, continuing at a later time.
#
# Finally, the `prepare_data_file` function readies the csv for storing the data. If the index we retrieved is 0, it means we are either starting for the first time or starting over. In either case, we want a blank csv file with only the header row to begin writing to, se we wipe the file (by opening in write mode) and write the header. Conversely, if the index is anything other than 0, it means we already have downloaded information, and can leave the csv file alone.

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# ## Download Steam Data
#
# Now we are ready to start downloading data and writing to file. We define our logic particular to handling the steam API - in fact if no data is returned we return just the name and appid - then begin setting some parameters. We define the files we will write our data and index to, and the columns for the csv file. The API doesn't return every column for every app, so it is best to explicitly set these.
#
# Next we run our functions to set up the files, and make a call to `process_batches` to begin the process. Some additional parameters have been added for demonstration, to constrain the download to just a few rows and smaller batches. Removing these would allow the entire download process to be repeated.

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# Set file parameters
download_path = './data/download'
steam_app_data = 'steam_app_data'+data_id+'.csv'
steam_index = 'steam_index'+data_id+'.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
#reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)
print(index)
# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)

# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    end=end,
    batchsize=30, 
    pause=0.7
)
# Out:
# 28230
# Starting at index 28230:
#
# Exported lines 28230-28259 to steam_app_data1.csv. Batch 0 time: 0:00:48 (avg: 0:00:48, remaining: 2:08:23)
# Exported lines 28260-28289 to steam_app_data1.csv. Batch 1 time: 0:00:49 (avg: 0:00:48, remaining: 2:09:08)
# Exported lines 28290-28319 to steam_app_data1.csv. Batch 2 time: 0:00:48 (avg: 0:00:48, remaining: 2:07:47)
# Exported lines 28320-28349 to steam_app_data1.csv. Batch 3 time: 0:00:48 (avg: 0:00:48, remaining: 2:07:04)
# Exported lines 28350-28379 to steam_app_data1.csv. Batch 4 time: 0:00:47 (avg: 0:00:48, remaining: 2:05:50)
# Exported lines 28380-28409 to steam_app_data1.csv. Batch 5 time: 0:00:49 (avg: 0:00:48, remaining: 2:05:22)
# Exported lines 28410-28439 to steam_app_data1.csv. Batch 6 time: 0:00:48 (avg: 0:00:48, remaining: 2:04:40)
# Exported lines 28440-28469 to steam_app_data1.csv. Batch 7 time: 0:00:48 (avg: 0:00:48, remaining: 2:03:54)
# Exported lines 28470-28499 to steam_app_data1.csv. Batch 8 time: 0:00:48 (avg: 0:00:48, remaining: 2:03:07)
# Exported lines 28500-28529 to steam_app_data1.csv. Batch 9 time: 0:00:48 (avg: 0:00:48, remaining: 2:02:24)
# Exported lines 28530-28559 to steam_app_data1.csv. Batch 10 time: 0:00:48 (avg: 0:00:48, remaining: 2:01:39)
# Exported lines 28560-28589 to steam_app_data1.csv. Batch 11 time: 0:00:48 (avg: 0:00:48, remaining: 2:00:48)
# Exported lines 28590-28619 to steam_app_data1.csv. Batch 12 time: 0:00:47 (avg: 0:00:48, remaining: 1:59:52)
# Exported lines 28620-28649 to steam_app_data1.csv. Batch 13 time: 0:00:48 (avg: 0:00:48, remaining: 1:59:08)
# Exported lines 28650-28679 to steam_app_data1.csv. Batch 14 time: 0:00:50 (avg: 0:00:48, remaining: 1:58:39)
# Exported lines 28680-28709 to steam_app_data1.csv. Batch 15 time: 0:00:49 (avg: 0:00:48, remaining: 1:58:01)
# Exported lines 28710-28739 to steam_app_data1.csv. Batch 16 time: 0:00:50 (avg: 0:00:48, remaining: 1:57:26)
# Exported lines 28740-28769 to steam_app_data1.csv. Batch 17 time: 0:00:48 (avg: 0:00:48, remaining: 1:56:38)
# Exported lines 28770-28799 to steam_app_data1.csv. Batch 18 time: 0:00:49 (avg: 0:00:48, remaining: 1:55:53)
# Exported lines 28800-28829 to steam_app_data1.csv. Batch 19 time: 0:00:48 (avg: 0:00:48, remaining: 1:55:04)
# Exported lines 28830-28859 to steam_app_data1.csv. Batch 20 time: 0:00:48 (avg: 0:00:48, remaining: 1:54:15)
# Exported lines 28860-28889 to steam_app_data1.csv. Batch 21 time: 0:00:48 (avg: 0:00:48, remaining: 1:53:27)
# Exported lines 28890-28919 to steam_app_data1.csv. Batch 22 time: 0:00:49 (avg: 0:00:48, remaining: 1:52:40)
# Exported lines 28920-28949 to steam_app_data1.csv. Batch 23 time: 0:00:49 (avg: 0:00:48, remaining: 1:51:54)
# Exported lines 28950-28979 to steam_app_data1.csv. Batch 24 time: 0:00:49 (avg: 0:00:48, remaining: 1:51:08)
# Exported lines 28980-29009 to steam_app_data1.csv. Batch 25 time: 0:00:49 (avg: 0:00:48, remaining: 1:50:21)
# Exported lines 29010-29039 to steam_app_data1.csv. Batch 26 time: 0:00:49 (avg: 0:00:48, remaining: 1:49:34)
# Exported lines 29040-29069 to steam_app_data1.csv. Batch 27 time: 0:00:48 (avg: 0:00:48, remaining: 1:48:43)
# Exported lines 29070-29099 to steam_app_data1.csv. Batch 28 time: 0:00:48 (avg: 0:00:48, remaining: 1:47:55)
# Exported lines 29100-29129 to steam_app_data1.csv. Batch 29 time: 0:00:48 (avg: 0:00:48, remaining: 1:47:05)
# Exported lines 29130-29159 to steam_app_data1.csv. Batch 30 time: 0:00:49 (avg: 0:00:48, remaining: 1:46:18)
# Exported lines 29160-29189 to steam_app_data1.csv. Batch 31 time: 0:00:47 (avg: 0:00:48, remaining: 1:45:26)
# Exported lines 29190-29219 to steam_app_data1.csv. Batch 32 time: 0:00:49 (avg: 0:00:48, remaining: 1:44:41)
# Exported lines 29220-29249 to steam_app_data1.csv. Batch 33 time: 0:00:48 (avg: 0:00:48, remaining: 1:43:50)
# Exported lines 29250-29279 to steam_app_data1.csv. Batch 34 time: 0:00:47 (avg: 0:00:48, remaining: 1:42:58)
# Exported lines 29280-29309 to steam_app_data1.csv. Batch 35 time: 0:00:48 (avg: 0:00:48, remaining: 1:42:09)
# Exported lines 29310-29339 to steam_app_data1.csv. Batch 36 time: 0:00:47 (avg: 0:00:48, remaining: 1:41:15)
# Exported lines 29340-29369 to steam_app_data1.csv. Batch 37 time: 0:00:47 (avg: 0:00:48, remaining: 1:40:23)
# Exported lines 29370-29399 to steam_app_data1.csv. Batch 38 time: 0:00:48 (avg: 0:00:48, remaining: 1:39:33)
# Exported lines 29400-29429 to steam_app_data1.csv. Batch 39 time: 0:00:46 (avg: 0:00:48, remaining: 1:38:38)
# Exported lines 29430-29459 to steam_app_data1.csv. Batch 40 time: 0:00:47 (avg: 0:00:48, remaining: 1:37:46)
# Exported lines 29460-29489 to steam_app_data1.csv. Batch 41 time: 0:00:46 (avg: 0:00:48, remaining: 1:36:53)
# Exported lines 29490-29519 to steam_app_data1.csv. Batch 42 time: 0:00:45 (avg: 0:00:48, remaining: 1:35:57)
# Exported lines 29520-29549 to steam_app_data1.csv. Batch 43 time: 0:00:48 (avg: 0:00:48, remaining: 1:35:08)
# Exported lines 29550-29579 to steam_app_data1.csv. Batch 44 time: 0:00:47 (avg: 0:00:48, remaining: 1:34:17)
# Exported lines 29580-29609 to steam_app_data1.csv. Batch 45 time: 0:00:48 (avg: 0:00:48, remaining: 1:33:29)
# Exported lines 29610-29639 to steam_app_data1.csv. Batch 46 time: 0:00:50 (avg: 0:00:48, remaining: 1:32:46)
# Exported lines 29640-29669 to steam_app_data1.csv. Batch 47 time: 0:00:48 (avg: 0:00:48, remaining: 1:31:58)
# Exported lines 29670-29699 to steam_app_data1.csv. Batch 48 time: 0:00:47 (avg: 0:00:48, remaining: 1:31:08)
# Exported lines 29700-29729 to steam_app_data1.csv. Batch 49 time: 0:00:47 (avg: 0:00:48, remaining: 1:30:18)
# Exported lines 29730-29759 to steam_app_data1.csv. Batch 50 time: 0:00:47 (avg: 0:00:48, remaining: 1:29:29)
# Exported lines 29760-29789 to steam_app_data1.csv. Batch 51 time: 0:00:49 (avg: 0:00:48, remaining: 1:28:43)
# Exported lines 29790-29819 to steam_app_data1.csv. Batch 52 time: 0:00:48 (avg: 0:00:48, remaining: 1:27:55)
# Exported lines 29820-29849 to steam_app_data1.csv. Batch 53 time: 0:00:47 (avg: 0:00:48, remaining: 1:27:05)
# Exported lines 29850-29879 to steam_app_data1.csv. Batch 54 time: 0:00:47 (avg: 0:00:48, remaining: 1:26:15)
# Exported lines 29880-29909 to steam_app_data1.csv. Batch 55 time: 0:00:47 (avg: 0:00:48, remaining: 1:25:26)
# Exported lines 29910-29939 to steam_app_data1.csv. Batch 56 time: 0:00:48 (avg: 0:00:48, remaining: 1:24:38)
# Exported lines 29940-29969 to steam_app_data1.csv. Batch 57 time: 0:00:48 (avg: 0:00:48, remaining: 1:23:50)
# Exported lines 29970-29999 to steam_app_data1.csv. Batch 58 time: 0:00:47 (avg: 0:00:48, remaining: 1:23:00)
# Exported lines 30000-30029 to steam_app_data1.csv. Batch 59 time: 0:00:48 (avg: 0:00:48, remaining: 1:22:13)
# Exported lines 30030-30059 to steam_app_data1.csv. Batch 60 time: 0:00:48 (avg: 0:00:48, remaining: 1:21:25)
# Exported lines 30060-30089 to steam_app_data1.csv. Batch 61 time: 0:00:47 (avg: 0:00:48, remaining: 1:20:36)
# Exported lines 30090-30119 to steam_app_data1.csv. Batch 62 time: 0:00:48 (avg: 0:00:48, remaining: 1:19:48)
# Exported lines 30120-30149 to steam_app_data1.csv. Batch 63 time: 0:00:48 (avg: 0:00:48, remaining: 1:19:01)
# Exported lines 30150-30179 to steam_app_data1.csv. Batch 64 time: 0:00:48 (avg: 0:00:48, remaining: 1:18:13)
# Exported lines 30180-30209 to steam_app_data1.csv. Batch 65 time: 0:00:48 (avg: 0:00:48, remaining: 1:17:25)
# Exported lines 30210-30239 to steam_app_data1.csv. Batch 66 time: 0:00:48 (avg: 0:00:48, remaining: 1:16:37)
# Exported lines 30240-30269 to steam_app_data1.csv. Batch 67 time: 0:00:48 (avg: 0:00:48, remaining: 1:15:49)
# Exported lines 30270-30299 to steam_app_data1.csv. Batch 68 time: 0:00:46 (avg: 0:00:48, remaining: 1:14:58)
# Exported lines 30300-30329 to steam_app_data1.csv. Batch 69 time: 0:00:47 (avg: 0:00:48, remaining: 1:14:10)
# Exported lines 30330-30359 to steam_app_data1.csv. Batch 70 time: 0:00:48 (avg: 0:00:48, remaining: 1:13:22)
# Exported lines 30360-30389 to steam_app_data1.csv. Batch 71 time: 0:00:48 (avg: 0:00:48, remaining: 1:12:34)
# Exported lines 30390-30419 to steam_app_data1.csv. Batch 72 time: 0:00:47 (avg: 0:00:48, remaining: 1:11:45)
# Exported lines 30420-30449 to steam_app_data1.csv. Batch 73 time: 0:00:48 (avg: 0:00:48, remaining: 1:10:57)
# Exported lines 30450-30479 to steam_app_data1.csv. Batch 74 time: 0:00:48 (avg: 0:00:48, remaining: 1:10:09)
# Exported lines 30480-30509 to steam_app_data1.csv. Batch 75 time: 0:00:49 (avg: 0:00:48, remaining: 1:09:22)
# Exported lines 30510-30539 to steam_app_data1.csv. Batch 76 time: 0:00:48 (avg: 0:00:48, remaining: 1:08:35)
# Exported lines 30540-30569 to steam_app_data1.csv. Batch 77 time: 0:00:48 (avg: 0:00:48, remaining: 1:07:47)
# Exported lines 30570-30599 to steam_app_data1.csv. Batch 78 time: 0:00:48 (avg: 0:00:48, remaining: 1:07:00)
# Exported lines 30600-30629 to steam_app_data1.csv. Batch 79 time: 0:00:48 (avg: 0:00:48, remaining: 1:06:12)
# Exported lines 30630-30659 to steam_app_data1.csv. Batch 80 time: 0:00:48 (avg: 0:00:48, remaining: 1:05:24)
# Exported lines 30660-30689 to steam_app_data1.csv. Batch 81 time: 0:00:47 (avg: 0:00:48, remaining: 1:04:36)
# Exported lines 30690-30719 to steam_app_data1.csv. Batch 82 time: 0:00:47 (avg: 0:00:48, remaining: 1:03:47)
# Exported lines 30720-30749 to steam_app_data1.csv. Batch 83 time: 0:00:49 (avg: 0:00:48, remaining: 1:03:00)
# Exported lines 30750-30779 to steam_app_data1.csv. Batch 84 time: 0:00:48 (avg: 0:00:48, remaining: 1:02:12)
# Exported lines 30780-30809 to steam_app_data1.csv. Batch 85 time: 0:00:49 (avg: 0:00:48, remaining: 1:01:25)
# Exported lines 30810-30839 to steam_app_data1.csv. Batch 86 time: 0:00:49 (avg: 0:00:48, remaining: 1:00:39)
# Exported lines 30840-30869 to steam_app_data1.csv. Batch 87 time: 0:00:47 (avg: 0:00:48, remaining: 0:59:50)
# Exported lines 30870-30899 to steam_app_data1.csv. Batch 88 time: 0:00:47 (avg: 0:00:48, remaining: 0:59:02)
# Exported lines 30900-30929 to steam_app_data1.csv. Batch 89 time: 0:00:48 (avg: 0:00:48, remaining: 0:58:14)
# Exported lines 30930-30959 to steam_app_data1.csv. Batch 90 time: 0:00:48 (avg: 0:00:48, remaining: 0:57:26)
# Exported lines 30960-30989 to steam_app_data1.csv. Batch 91 time: 0:00:47 (avg: 0:00:48, remaining: 0:56:38)
# Exported lines 30990-31019 to steam_app_data1.csv. Batch 92 time: 0:00:47 (avg: 0:00:48, remaining: 0:55:49)
# Exported lines 31020-31049 to steam_app_data1.csv. Batch 93 time: 0:00:48 (avg: 0:00:48, remaining: 0:55:02)
# Exported lines 31050-31079 to steam_app_data1.csv. Batch 94 time: 0:00:47 (avg: 0:00:48, remaining: 0:54:13)
# Exported lines 31080-31109 to steam_app_data1.csv. Batch 95 time: 0:00:47 (avg: 0:00:48, remaining: 0:53:24)
# Exported lines 31110-31139 to steam_app_data1.csv. Batch 96 time: 0:00:46 (avg: 0:00:48, remaining: 0:52:36)
# Exported lines 31140-31169 to steam_app_data1.csv. Batch 97 time: 0:00:47 (avg: 0:00:48, remaining: 0:51:47)
# Exported lines 31170-31199 to steam_app_data1.csv. Batch 98 time: 0:00:47 (avg: 0:00:48, remaining: 0:50:59)
# Exported lines 31200-31229 to steam_app_data1.csv. Batch 99 time: 0:00:47 (avg: 0:00:48, remaining: 0:50:10)
# Exported lines 31230-31259 to steam_app_data1.csv. Batch 100 time: 0:00:47 (avg: 0:00:48, remaining: 0:49:22)
# Exported lines 31260-31289 to steam_app_data1.csv. Batch 101 time: 0:00:47 (avg: 0:00:48, remaining: 0:48:34)
# Exported lines 31290-31319 to steam_app_data1.csv. Batch 102 time: 0:00:47 (avg: 0:00:48, remaining: 0:47:46)
# Exported lines 31320-31349 to steam_app_data1.csv. Batch 103 time: 0:00:48 (avg: 0:00:48, remaining: 0:46:58)
# Exported lines 31350-31379 to steam_app_data1.csv. Batch 104 time: 0:00:47 (avg: 0:00:48, remaining: 0:46:10)
# Exported lines 31380-31409 to steam_app_data1.csv. Batch 105 time: 0:00:47 (avg: 0:00:48, remaining: 0:45:22)
# Exported lines 31410-31439 to steam_app_data1.csv. Batch 106 time: 0:00:48 (avg: 0:00:48, remaining: 0:44:34)
# Exported lines 31440-31469 to steam_app_data1.csv. Batch 107 time: 0:00:48 (avg: 0:00:48, remaining: 0:43:47)
# Exported lines 31470-31499 to steam_app_data1.csv. Batch 108 time: 0:00:49 (avg: 0:00:48, remaining: 0:42:59)
# Exported lines 31500-31529 to steam_app_data1.csv. Batch 109 time: 0:00:48 (avg: 0:00:48, remaining: 0:42:12)
# Exported lines 31530-31559 to steam_app_data1.csv. Batch 110 time: 0:00:47 (avg: 0:00:48, remaining: 0:41:24)
# Exported lines 31560-31589 to steam_app_data1.csv. Batch 111 time: 0:00:47 (avg: 0:00:48, remaining: 0:40:36)
# Exported lines 31590-31619 to steam_app_data1.csv. Batch 112 time: 0:00:47 (avg: 0:00:48, remaining: 0:39:48)
# Exported lines 31620-31649 to steam_app_data1.csv. Batch 113 time: 0:00:49 (avg: 0:00:48, remaining: 0:39:00)
# Exported lines 31650-31679 to steam_app_data1.csv. Batch 114 time: 0:00:47 (avg: 0:00:48, remaining: 0:38:12)
# Exported lines 31680-31709 to steam_app_data1.csv. Batch 115 time: 0:00:48 (avg: 0:00:48, remaining: 0:37:25)
# Exported lines 31710-31739 to steam_app_data1.csv. Batch 116 time: 0:00:49 (avg: 0:00:48, remaining: 0:36:38)
# Exported lines 31740-31769 to steam_app_data1.csv. Batch 117 time: 0:00:49 (avg: 0:00:48, remaining: 0:35:50)
# Exported lines 31770-31799 to steam_app_data1.csv. Batch 118 time: 0:00:49 (avg: 0:00:48, remaining: 0:35:03)
# Exported lines 31800-31829 to steam_app_data1.csv. Batch 119 time: 0:00:49 (avg: 0:00:48, remaining: 0:34:16)
# Exported lines 31830-31859 to steam_app_data1.csv. Batch 120 time: 0:00:48 (avg: 0:00:48, remaining: 0:33:28)
# Exported lines 31860-31889 to steam_app_data1.csv. Batch 121 time: 0:00:48 (avg: 0:00:48, remaining: 0:32:40)
# Exported lines 31890-31919 to steam_app_data1.csv. Batch 122 time: 0:00:49 (avg: 0:00:48, remaining: 0:31:53)
# Exported lines 31920-31949 to steam_app_data1.csv. Batch 123 time: 0:00:49 (avg: 0:00:48, remaining: 0:31:05)
# Exported lines 31950-31979 to steam_app_data1.csv. Batch 124 time: 0:00:47 (avg: 0:00:48, remaining: 0:30:17)
# Exported lines 31980-32009 to steam_app_data1.csv. Batch 125 time: 0:00:48 (avg: 0:00:48, remaining: 0:29:29)
# Exported lines 32010-32039 to steam_app_data1.csv. Batch 126 time: 0:00:48 (avg: 0:00:48, remaining: 0:28:41)
# Exported lines 32040-32069 to steam_app_data1.csv. Batch 127 time: 0:00:47 (avg: 0:00:48, remaining: 0:27:54)
# Exported lines 32070-32099 to steam_app_data1.csv. Batch 128 time: 0:00:49 (avg: 0:00:48, remaining: 0:27:06)
# Exported lines 32100-32129 to steam_app_data1.csv. Batch 129 time: 0:00:48 (avg: 0:00:48, remaining: 0:26:18)
# Exported lines 32130-32159 to steam_app_data1.csv. Batch 130 time: 0:00:47 (avg: 0:00:48, remaining: 0:25:30)
# Exported lines 32160-32189 to steam_app_data1.csv. Batch 131 time: 0:00:47 (avg: 0:00:48, remaining: 0:24:42)
# Exported lines 32190-32219 to steam_app_data1.csv. Batch 132 time: 0:00:47 (avg: 0:00:48, remaining: 0:23:54)
# Exported lines 32220-32249 to steam_app_data1.csv. Batch 133 time: 0:00:47 (avg: 0:00:48, remaining: 0:23:06)
# Exported lines 32250-32279 to steam_app_data1.csv. Batch 134 time: 0:00:47 (avg: 0:00:48, remaining: 0:22:18)
# Exported lines 32280-32309 to steam_app_data1.csv. Batch 135 time: 0:00:47 (avg: 0:00:48, remaining: 0:21:30)
# Exported lines 32310-32339 to steam_app_data1.csv. Batch 136 time: 0:00:47 (avg: 0:00:48, remaining: 0:20:42)
# Exported lines 32340-32369 to steam_app_data1.csv. Batch 137 time: 0:00:47 (avg: 0:00:48, remaining: 0:19:54)
# Exported lines 32370-32399 to steam_app_data1.csv. Batch 138 time: 0:00:47 (avg: 0:00:48, remaining: 0:19:06)
# Exported lines 32400-32429 to steam_app_data1.csv. Batch 139 time: 0:00:47 (avg: 0:00:48, remaining: 0:18:19)
# Exported lines 32430-32459 to steam_app_data1.csv. Batch 140 time: 0:00:47 (avg: 0:00:48, remaining: 0:17:31)
# Exported lines 32460-32489 to steam_app_data1.csv. Batch 141 time: 0:00:49 (avg: 0:00:48, remaining: 0:16:43)
# Exported lines 32490-32519 to steam_app_data1.csv. Batch 142 time: 0:00:47 (avg: 0:00:48, remaining: 0:15:55)
# Exported lines 32520-32549 to steam_app_data1.csv. Batch 143 time: 0:00:47 (avg: 0:00:48, remaining: 0:15:07)
# Exported lines 32550-32579 to steam_app_data1.csv. Batch 144 time: 0:00:47 (avg: 0:00:48, remaining: 0:14:20)
# Exported lines 32580-32609 to steam_app_data1.csv. Batch 145 time: 0:00:47 (avg: 0:00:48, remaining: 0:13:32)
# Exported lines 32610-32639 to steam_app_data1.csv. Batch 146 time: 0:00:47 (avg: 0:00:48, remaining: 0:12:44)
# Exported lines 32640-32669 to steam_app_data1.csv. Batch 147 time: 0:00:48 (avg: 0:00:48, remaining: 0:11:56)
# Exported lines 32670-32699 to steam_app_data1.csv. Batch 148 time: 0:00:46 (avg: 0:00:48, remaining: 0:11:08)
# Exported lines 32700-32729 to steam_app_data1.csv. Batch 149 time: 0:00:49 (avg: 0:00:48, remaining: 0:10:21)
# Exported lines 32730-32759 to steam_app_data1.csv. Batch 150 time: 0:00:47 (avg: 0:00:48, remaining: 0:09:33)
# Exported lines 32760-32789 to steam_app_data1.csv. Batch 151 time: 0:00:47 (avg: 0:00:48, remaining: 0:08:45)
# Exported lines 32790-32819 to steam_app_data1.csv. Batch 152 time: 0:00:47 (avg: 0:00:48, remaining: 0:07:57)
# Exported lines 32820-32849 to steam_app_data1.csv. Batch 153 time: 0:00:47 (avg: 0:00:48, remaining: 0:07:09)
# Exported lines 32850-32879 to steam_app_data1.csv. Batch 154 time: 0:00:48 (avg: 0:00:48, remaining: 0:06:22)
# Exported lines 32880-32909 to steam_app_data1.csv. Batch 155 time: 0:00:46 (avg: 0:00:48, remaining: 0:05:34)
# Exported lines 32910-32939 to steam_app_data1.csv. Batch 156 time: 0:00:47 (avg: 0:00:48, remaining: 0:04:46)
# Exported lines 32940-32969 to steam_app_data1.csv. Batch 157 time: 0:00:48 (avg: 0:00:48, remaining: 0:03:59)
# Exported lines 32970-32999 to steam_app_data1.csv. Batch 158 time: 0:00:47 (avg: 0:00:48, remaining: 0:03:11)
# Exported lines 33000-33029 to steam_app_data1.csv. Batch 159 time: 0:00:47 (avg: 0:00:48, remaining: 0:02:23)
# Exported lines 33030-33059 to steam_app_data1.csv. Batch 160 time: 0:00:47 (avg: 0:00:48, remaining: 0:01:35)
# Exported lines 33060-33089 to steam_app_data1.csv. Batch 161 time: 0:00:47 (avg: 0:00:48, remaining: 0:00:48)
# Exported lines 33090-33099 to steam_app_data1.csv. Batch 162 time: 0:00:15 (avg: 0:00:47, remaining: 0:00:00)
#
# Processing batches complete. 4869 apps written

# %%
# inspect downloaded data
raw_steam_data = pd.read_csv('./data/download/steam_app_data'+data_id+'.csv')
print(len(raw_steam_data))
pd.read_csv('./data/download/steam_app_data'+data_id+'.csv').head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (4,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 32979
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
# 1  One of the most popular online action games of...       NaN
# 2  Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3  Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4  Return to the Black Mesa Research Facility as ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice            developers publishers demos  \
# 0                     NaN             ['Valve']  ['Valve']   NaN
# 1                     NaN             ['Valve']  ['Valve']   NaN
# 2                     NaN             ['Valve']  ['Valve']   NaN
# 3                     NaN             ['Valve']  ['Valve']   NaN
# 4                     NaN  ['Gearbox Software']  ['Valve']   NaN
#
#                                       price_overview packages  \
# 0  {'currency': 'EUR', 'initial': 819, 'final': 8...      [7]
# 1  {'currency': 'EUR', 'initial': 399, 'final': 3...     [29]
# 2  {'currency': 'EUR', 'initial': 399, 'final': 3...     [30]
# 3  {'currency': 'EUR', 'initial': 399, 'final': 3...     [31]
# 4  {'currency': 'EUR', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies   recommendations  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 80765}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 3245}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 2398}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 1122}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 5553}
#
#    achievements                                   release_date  \
# 0  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'total': 0}  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'total': 0}  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'total': 0}  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# ## Download SteamSpy data
#
# To retrieve data from SteamSpy we perform a very similar process. Our parse function is a little simpler because of the how data is returned, and the maximum polling rate of this API is higher so we can set a lower value for `pause` in the `process_batches` function and download more quickly. Apart from that we set the new variables and make a call to the `process_batches` function once again.

# %%
def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data


# set files and columns
download_path = './data/download'
steamspy_data = 'steamspy_data'+data_id+'.csv'
steamspy_index = 'steamspy_index'+data_id+'.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

#reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    end=end,
    batchsize=20,
    pause=0.1
)
# Out:
# Starting at index 30100:
#
# Exported lines 30100-30119 to steamspy_data1.csv. Batch 0 time: 0:00:06 (avg: 0:00:06, remaining: 0:15:08)
# Exported lines 30120-30139 to steamspy_data1.csv. Batch 1 time: 0:00:09 (avg: 0:00:07, remaining: 0:18:09)
# Exported lines 30140-30159 to steamspy_data1.csv. Batch 2 time: 0:00:05 (avg: 0:00:07, remaining: 0:16:12)
# Exported lines 30160-30179 to steamspy_data1.csv. Batch 3 time: 0:00:05 (avg: 0:00:06, remaining: 0:15:07)
# Exported lines 30180-30199 to steamspy_data1.csv. Batch 4 time: 0:00:05 (avg: 0:00:06, remaining: 0:14:26)
# Exported lines 30200-30219 to steamspy_data1.csv. Batch 5 time: 0:00:06 (avg: 0:00:06, remaining: 0:14:22)
# Exported lines 30220-30239 to steamspy_data1.csv. Batch 6 time: 0:00:05 (avg: 0:00:06, remaining: 0:13:56)
# Exported lines 30240-30259 to steamspy_data1.csv. Batch 7 time: 0:00:05 (avg: 0:00:06, remaining: 0:13:34)
# Exported lines 30260-30279 to steamspy_data1.csv. Batch 8 time: 0:00:05 (avg: 0:00:06, remaining: 0:13:16)
# Exported lines 30280-30299 to steamspy_data1.csv. Batch 9 time: 0:00:05 (avg: 0:00:06, remaining: 0:13:01)
# Exported lines 30300-30319 to steamspy_data1.csv. Batch 10 time: 0:00:05 (avg: 0:00:06, remaining: 0:12:48)
# Exported lines 30320-30339 to steamspy_data1.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 0:12:37)
# Exported lines 30340-30359 to steamspy_data1.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 0:12:27)
# Exported lines 30360-30379 to steamspy_data1.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 0:12:17)
# Exported lines 30380-30399 to steamspy_data1.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 0:12:07)
# Exported lines 30400-30419 to steamspy_data1.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:58)
# Exported lines 30420-30439 to steamspy_data1.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:50)
# Exported lines 30440-30459 to steamspy_data1.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:42)
# Exported lines 30460-30479 to steamspy_data1.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:34)
# Exported lines 30480-30499 to steamspy_data1.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:27)
# Exported lines 30500-30519 to steamspy_data1.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:20)
# Exported lines 30520-30539 to steamspy_data1.csv. Batch 21 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:12)
# Exported lines 30540-30559 to steamspy_data1.csv. Batch 22 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:05)
# Exported lines 30560-30579 to steamspy_data1.csv. Batch 23 time: 0:00:05 (avg: 0:00:05, remaining: 0:11:00)
# Exported lines 30580-30599 to steamspy_data1.csv. Batch 24 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:55)
# Exported lines 30600-30619 to steamspy_data1.csv. Batch 25 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:49)
# Exported lines 30620-30639 to steamspy_data1.csv. Batch 26 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:43)
# Exported lines 30640-30659 to steamspy_data1.csv. Batch 27 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:37)
# Exported lines 30660-30679 to steamspy_data1.csv. Batch 28 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:31)
# Exported lines 30680-30699 to steamspy_data1.csv. Batch 29 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:25)
# Exported lines 30700-30719 to steamspy_data1.csv. Batch 30 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:19)
# Exported lines 30720-30739 to steamspy_data1.csv. Batch 31 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:13)
# Exported lines 30740-30759 to steamspy_data1.csv. Batch 32 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:08)
# Exported lines 30760-30779 to steamspy_data1.csv. Batch 33 time: 0:00:05 (avg: 0:00:05, remaining: 0:10:02)
# Exported lines 30780-30799 to steamspy_data1.csv. Batch 34 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:57)
# Exported lines 30800-30819 to steamspy_data1.csv. Batch 35 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:51)
# Exported lines 30820-30839 to steamspy_data1.csv. Batch 36 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:46)
# Exported lines 30840-30859 to steamspy_data1.csv. Batch 37 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:40)
# Exported lines 30860-30879 to steamspy_data1.csv. Batch 38 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:35)
# Exported lines 30880-30899 to steamspy_data1.csv. Batch 39 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:30)
# Exported lines 30900-30919 to steamspy_data1.csv. Batch 40 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:24)
# Exported lines 30920-30939 to steamspy_data1.csv. Batch 41 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:19)
# Exported lines 30940-30959 to steamspy_data1.csv. Batch 42 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:13)
# Exported lines 30960-30979 to steamspy_data1.csv. Batch 43 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:08)
# Exported lines 30980-30999 to steamspy_data1.csv. Batch 44 time: 0:00:05 (avg: 0:00:05, remaining: 0:09:03)
# Exported lines 31000-31019 to steamspy_data1.csv. Batch 45 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:58)
# Exported lines 31020-31039 to steamspy_data1.csv. Batch 46 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:52)
# Exported lines 31040-31059 to steamspy_data1.csv. Batch 47 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:47)
# Exported lines 31060-31079 to steamspy_data1.csv. Batch 48 time: 0:00:06 (avg: 0:00:05, remaining: 0:08:43)
# Exported lines 31080-31099 to steamspy_data1.csv. Batch 49 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:37)
# Exported lines 31100-31119 to steamspy_data1.csv. Batch 50 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:32)
# Exported lines 31120-31139 to steamspy_data1.csv. Batch 51 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:26)
# Exported lines 31140-31159 to steamspy_data1.csv. Batch 52 time: 0:00:06 (avg: 0:00:05, remaining: 0:08:23)
# Exported lines 31160-31179 to steamspy_data1.csv. Batch 53 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:18)
# Exported lines 31180-31199 to steamspy_data1.csv. Batch 54 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:13)
# Exported lines 31200-31219 to steamspy_data1.csv. Batch 55 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:07)
# Exported lines 31220-31239 to steamspy_data1.csv. Batch 56 time: 0:00:05 (avg: 0:00:05, remaining: 0:08:02)
# Exported lines 31240-31259 to steamspy_data1.csv. Batch 57 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:57)
# Exported lines 31260-31279 to steamspy_data1.csv. Batch 58 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:51)
# Exported lines 31280-31299 to steamspy_data1.csv. Batch 59 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:46)
# Exported lines 31300-31319 to steamspy_data1.csv. Batch 60 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:41)
# Exported lines 31320-31339 to steamspy_data1.csv. Batch 61 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:35)
# Exported lines 31340-31359 to steamspy_data1.csv. Batch 62 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:30)
# Exported lines 31360-31379 to steamspy_data1.csv. Batch 63 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:25)
# Exported lines 31380-31399 to steamspy_data1.csv. Batch 64 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:20)
# Exported lines 31400-31419 to steamspy_data1.csv. Batch 65 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:14)
# Exported lines 31420-31439 to steamspy_data1.csv. Batch 66 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:09)
# Exported lines 31440-31459 to steamspy_data1.csv. Batch 67 time: 0:00:05 (avg: 0:00:05, remaining: 0:07:04)
# Exported lines 31460-31479 to steamspy_data1.csv. Batch 68 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:58)
# Exported lines 31480-31499 to steamspy_data1.csv. Batch 69 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:53)
# Exported lines 31500-31519 to steamspy_data1.csv. Batch 70 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:48)
# Exported lines 31520-31539 to steamspy_data1.csv. Batch 71 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:43)
# Exported lines 31540-31559 to steamspy_data1.csv. Batch 72 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:37)
# Exported lines 31560-31579 to steamspy_data1.csv. Batch 73 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:32)
# Exported lines 31580-31599 to steamspy_data1.csv. Batch 74 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:27)
# Exported lines 31600-31619 to steamspy_data1.csv. Batch 75 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:22)
# Exported lines 31620-31639 to steamspy_data1.csv. Batch 76 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:16)
# Exported lines 31640-31659 to steamspy_data1.csv. Batch 77 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:11)
# Exported lines 31660-31679 to steamspy_data1.csv. Batch 78 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:06)
# Exported lines 31680-31699 to steamspy_data1.csv. Batch 79 time: 0:00:05 (avg: 0:00:05, remaining: 0:06:01)
# Exported lines 31700-31719 to steamspy_data1.csv. Batch 80 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:56)
# Exported lines 31720-31739 to steamspy_data1.csv. Batch 81 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:50)
# Exported lines 31740-31759 to steamspy_data1.csv. Batch 82 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:45)
# Exported lines 31760-31779 to steamspy_data1.csv. Batch 83 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:40)
# Exported lines 31780-31799 to steamspy_data1.csv. Batch 84 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:35)
# Exported lines 31800-31819 to steamspy_data1.csv. Batch 85 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:30)
# Exported lines 31820-31839 to steamspy_data1.csv. Batch 86 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:25)
# Exported lines 31840-31859 to steamspy_data1.csv. Batch 87 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:19)
# Exported lines 31860-31879 to steamspy_data1.csv. Batch 88 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:14)
# Exported lines 31880-31899 to steamspy_data1.csv. Batch 89 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:09)
# Exported lines 31900-31919 to steamspy_data1.csv. Batch 90 time: 0:00:05 (avg: 0:00:05, remaining: 0:05:04)
# Exported lines 31920-31939 to steamspy_data1.csv. Batch 91 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:59)
# Exported lines 31940-31959 to steamspy_data1.csv. Batch 92 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:53)
# Exported lines 31960-31979 to steamspy_data1.csv. Batch 93 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:48)
# Exported lines 31980-31999 to steamspy_data1.csv. Batch 94 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:43)
# Exported lines 32000-32019 to steamspy_data1.csv. Batch 95 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:38)
# Exported lines 32020-32039 to steamspy_data1.csv. Batch 96 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:32)
# Exported lines 32040-32059 to steamspy_data1.csv. Batch 97 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:27)
# Exported lines 32060-32079 to steamspy_data1.csv. Batch 98 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:22)
# Exported lines 32080-32099 to steamspy_data1.csv. Batch 99 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:17)
# Exported lines 32100-32119 to steamspy_data1.csv. Batch 100 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:12)
# Exported lines 32120-32139 to steamspy_data1.csv. Batch 101 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:07)
# Exported lines 32140-32159 to steamspy_data1.csv. Batch 102 time: 0:00:05 (avg: 0:00:05, remaining: 0:04:01)
# Exported lines 32160-32179 to steamspy_data1.csv. Batch 103 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:56)
# Exported lines 32180-32199 to steamspy_data1.csv. Batch 104 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:51)
# Exported lines 32200-32219 to steamspy_data1.csv. Batch 105 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:46)
# Exported lines 32220-32239 to steamspy_data1.csv. Batch 106 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:41)
# Exported lines 32240-32259 to steamspy_data1.csv. Batch 107 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:36)
# Exported lines 32260-32279 to steamspy_data1.csv. Batch 108 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:31)
# Exported lines 32280-32299 to steamspy_data1.csv. Batch 109 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:25)
# Exported lines 32300-32319 to steamspy_data1.csv. Batch 110 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:20)
# Exported lines 32320-32339 to steamspy_data1.csv. Batch 111 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:15)
# Exported lines 32340-32359 to steamspy_data1.csv. Batch 112 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:10)
# Exported lines 32360-32379 to steamspy_data1.csv. Batch 113 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:05)
# Exported lines 32380-32399 to steamspy_data1.csv. Batch 114 time: 0:00:05 (avg: 0:00:05, remaining: 0:03:00)
# Exported lines 32400-32419 to steamspy_data1.csv. Batch 115 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:55)
# Exported lines 32420-32439 to steamspy_data1.csv. Batch 116 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:50)
# Exported lines 32440-32459 to steamspy_data1.csv. Batch 117 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:44)
# Exported lines 32460-32479 to steamspy_data1.csv. Batch 118 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:39)
# Exported lines 32480-32499 to steamspy_data1.csv. Batch 119 time: 0:00:06 (avg: 0:00:05, remaining: 0:02:34)
# Exported lines 32500-32519 to steamspy_data1.csv. Batch 120 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:29)
# Exported lines 32520-32539 to steamspy_data1.csv. Batch 121 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:24)
# Exported lines 32540-32559 to steamspy_data1.csv. Batch 122 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:19)
# Exported lines 32560-32579 to steamspy_data1.csv. Batch 123 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:14)
# Exported lines 32580-32599 to steamspy_data1.csv. Batch 124 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:09)
# Exported lines 32600-32619 to steamspy_data1.csv. Batch 125 time: 0:00:05 (avg: 0:00:05, remaining: 0:02:03)
# Exported lines 32620-32639 to steamspy_data1.csv. Batch 126 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:58)
# Exported lines 32640-32659 to steamspy_data1.csv. Batch 127 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:53)
# Exported lines 32660-32679 to steamspy_data1.csv. Batch 128 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:48)
# Exported lines 32680-32699 to steamspy_data1.csv. Batch 129 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:43)
# Exported lines 32700-32719 to steamspy_data1.csv. Batch 130 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:38)
# Exported lines 32720-32739 to steamspy_data1.csv. Batch 131 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:33)
# Exported lines 32740-32759 to steamspy_data1.csv. Batch 132 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:27)
# Exported lines 32760-32779 to steamspy_data1.csv. Batch 133 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:22)
# Exported lines 32780-32799 to steamspy_data1.csv. Batch 134 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:17)
# Exported lines 32800-32819 to steamspy_data1.csv. Batch 135 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:12)
# Exported lines 32820-32839 to steamspy_data1.csv. Batch 136 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:07)
# Exported lines 32840-32859 to steamspy_data1.csv. Batch 137 time: 0:00:05 (avg: 0:00:05, remaining: 0:01:02)
# Exported lines 32860-32879 to steamspy_data1.csv. Batch 138 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:57)
# Exported lines 32880-32899 to steamspy_data1.csv. Batch 139 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:51)
# Exported lines 32900-32919 to steamspy_data1.csv. Batch 140 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:46)
# Exported lines 32920-32939 to steamspy_data1.csv. Batch 141 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:41)
# Exported lines 32940-32959 to steamspy_data1.csv. Batch 142 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:36)
# Exported lines 32960-32979 to steamspy_data1.csv. Batch 143 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:31)
# Exported lines 32980-32999 to steamspy_data1.csv. Batch 144 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:26)
# Exported lines 33000-33019 to steamspy_data1.csv. Batch 145 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:21)
# Exported lines 33020-33039 to steamspy_data1.csv. Batch 146 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:15)
# Exported lines 33040-33059 to steamspy_data1.csv. Batch 147 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:10)
# Exported lines 33060-33079 to steamspy_data1.csv. Batch 148 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:05)
# Exported lines 33080-33099 to steamspy_data1.csv. Batch 149 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:00)
#
# Processing batches complete. 2999 apps written

# %%
# inspect downloaded steamspy data
raw_steamspy_data = pd.read_csv('./data/download/steamspy_data'+data_id+'.csv')
raw_steamspy_data.head()
pd.read_csv('./data/download/steamspy_data'+data_id+'.csv').head()
# Out:
#    appid                       name         developer publisher  score_rank  \
# 0     10             Counter-Strike             Valve     Valve         NaN
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    144330      3754          0  20,000,000 .. 50,000,000            12988
# 1      3804       711          0    2,000,000 .. 5,000,000              129
# 2      3909       468          0   5,000,000 .. 10,000,000              184
# 3      1469       317          0   5,000,000 .. 10,000,000               36
# 4      6529       359          0   5,000,000 .. 10,000,000              197
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0             287             166             36  999.0         999.0
# 1             143              36            143  499.0         499.0
# 2             143              28            143  499.0         499.0
# 3             143              15            143  499.0         499.0
# 4             143             121            143  499.0         499.0
#
#    discount                                          languages   genre    ccu  \
# 0       0.0  English, French, German, Italian, Spanish - Sp...  Action  18041
# 1       0.0  English, French, German, Italian, Spanish - Sp...  Action     95
# 2       0.0  English, French, German, Italian, Spanish - Spain  Action    196
# 3       0.0  English, French, German, Italian, Spanish - Sp...  Action      9
# 4       0.0                    English, French, German, Korean  Action    202
#
#                                                 tags
# 0  {'Action': 5284, 'FPS': 4685, 'Multiplayer': 3...
# 1  {'Action': 722, 'FPS': 290, 'Multiplayer': 243...
# 2  {'FPS': 774, 'World War II': 241, 'Multiplayer...
# 3  {'Action': 622, 'FPS': 132, 'Classic': 101, 'M...
# 4  {'FPS': 860, 'Action': 280, 'Classic': 229, 'S...

# %% [markdown]
# ## Next Steps
#
# Here we have defined and demonstrated the download process used to generate the data sets.
# This process already completed can be found here on kaggle [on Kaggle](https://kaggle.com/nikdavis/steam-store-raw) [Only cover games until March 2019].
#
# We now have two tables of data with a variety of information about apps on the Steam store. From the Steam data it looks like there are some useful columns like `required_age`, `developers` and `genres` which we can eventually turn into features for analysis, and a `price_overview` column which may inform the success and sales of each game. The `owners` column of the SteamSpy data could be useful, however the [margin of error](https://steamspy.com/about) means data may not be accurate enough for meaningful analysis, we'll have to see what we can manage after cleaning. Instead we may have to use the `positive` and `negative` ratings or average play-time to create our metrics. There is also a `tags` column which appears to crossover with the `categories` and `genres` columns in the Steam data. We may wish to merge these, or keep one over the other.
#
# These are all decisions we'll come to in later stages of the project. With the data downloaded, this stage is now complete. In the next step, we'll take care of preparing and cleaning the data, readying a complete data set to use for analysis.
